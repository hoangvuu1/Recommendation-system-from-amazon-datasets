# %% [markdown]
# ## Load data (colab environment)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
PRODUCTS_PATH = 'drive/MyDrive/data - MoMD'

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import get_json_object, from_json, regexp_replace, col
from pyspark.sql.types import *

spark = SparkSession.builder.appName('Office').getOrCreate()

review_df = spark.read.json(PRODUCTS_PATH + '/Office_Products.jsonl')

# %%
meta_schema = StructType([
    StructField("main_category", StringType(), True),
    StructField("title", StringType(), True),
    StructField("average_rating", DoubleType(), True),
    StructField("rating_number", LongType(), True),
    StructField("features", ArrayType(StringType()), True),
    StructField("description", ArrayType(StringType()), True),
    StructField("price", DoubleType(), True),
    StructField("images", ArrayType(MapType(StringType(), StringType())), True),
    StructField("videos", ArrayType(MapType(StringType(), StringType())), True),
    StructField("store", StringType(), True),
    StructField("categories", ArrayType(StringType()), True),

    StructField("details", StringType(), True),

    StructField("parent_asin", StringType(), True),
    StructField("bought_together", DoubleType(), True),
    StructField("subtitle", StringType(), True),
    StructField("author", StringType(), True),
])

raw_meta_df = spark.read.text(PRODUCTS_PATH + "/meta_Office_Products.jsonl")

meta_df = (
    raw_meta_df
    .select(from_json(col("value"), meta_schema).alias("data"))
    .select("data.*")
)

# %% [markdown]
# ## Item

# %%
joined_df = review_df.join(
    meta_df.select("parent_asin"),
    on="parent_asin",
    how="left"
)

# %% [markdown]
# ### Reviews / item

# %%
from pyspark.sql.functions import count, avg

review_stat = joined_df.groupBy("parent_asin").agg(
    count("*").alias("review_count"),
    avg("rating").alias("avg_rating")
)

# %%
review_stat.describe().show()
# Out:
# +-------+--------------------+------------------+-----------------+
# |summary|         parent_asin|      review_count|       avg_rating|
# +-------+--------------------+------------------+-----------------+
# |  count|              710403|            710403|           710403|
# |   mean|1.9191196864709792E9|18.082288503849224|4.139702315329243|
# | stddev| 1.780190154219129E9|124.04239374339363|1.100193988228129|
# |    min|          0000306002|                 1|              1.0|
# |    max|          BT008UKTMW|             32645|              5.0|
# +-------+--------------------+------------------+-----------------+

# %% [markdown]
# ### Visualization

# %%
import matplotlib.pyplot as plt

# %%
rating_rdd = review_stat.rdd.map(lambda row: row.avg_rating)

# %%
bins, avg_ratings = rating_rdd.histogram(26)

# %%
plt.bar(bins[:-1], avg_ratings, width=0.9*(bins[1] - bins[0]))
plt.yscale("log")
plt.xlabel("Avg rating")
plt.ylabel("Item count (log transformed)")
plt.title("Ratings distribution")
plt.show()

# %% [markdown]
# ### Only 1 review rate

# %%
review_stat.filter(col("review_count") == 1).count()
# Out:
# 260634

# %% [markdown]
# ### Top 5 most rated items

# %%
top_asins = (
    review_stat
    .select("parent_asin", "review_count", "avg_rating")
    .rdd
    .takeOrdered(5, key=lambda x: -x.review_count)
)

top_asins = spark.createDataFrame(top_asins)

# %%
from pyspark.sql.functions import broadcast

top_items = top_asins.join(meta_df, on="parent_asin", how="left")

# %%
top_items.show(truncate=False)
# Out:
# +-----------+------------+------------------+---------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------+-------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |parent_asin|review_count|avg_rating        |main_category  |title                                                                                                                                                                                                  |average_rating|rating_number|features                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |price |images                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# +-----------+------------+------------------+---------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------+-------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |B0BZ67T58M |12135       |4.852575195714874 |Automotive     |Office Chair Wheels Replacement Rubber Chair casters for Hardwood Floors and Carpet, Set of 5, Heavy Duty Office Chair casters for Chairs to Replace Office Chair mats - Fits 98%                      |4.8           |44539        |[THE LAST OFFICE CHAIR WHEELS YOU'LL NEED – Not all caster wheels are created equal. Our heavy-duty chair wheels are made from industrial-grade steel, precision ball bearings, and durable polyurethane chair casters. Its not compatible with IKEA chairs and not either with some off brand chairs, our stem size is 7/16" x 7/8", DESK CHAIR MAT WILL NOT BE NEEDED ANYMORE – Our desk chair wheels replacement will NEVER scratch, smudge or damage your floors. Enjoy a carefree, safe glide across wood, hardwood, laminate, vinyl, tile and carpet floors all day long. P.S. Regarding the smooth rolling on carpet it depends on the pile carpet that you have, some roll better and some aren’t as smooth. High pile carpet usually rolls less smooth then low pile., REPLACEMENT FOR MOST OFFICE CHAIRS – Rest assured that our office chair wheels are compatible with almost any rolling chair (please check the size of your wheel stubs before ordering). IMPORTANT: NOT compatible with IKEA chairs." (our stem size is 7/16" x 7/8"), SMOOTH GLIDING IS AS QUIET AS A MOUSE – A squeaky, rickety office chair wheel is a telltale sign that they’re cheap and poorly made. You’ll slide and glide around in total silence with our swivel casters, YOUR TOTAL SATISFACTION IS OUR #1 PRIORITY – We put considerable effort into ensuring we created the best desk chair wheels on the planet. After a quick install and glide around, we’re positive you’ll agree. If by some miracle you don’t, we’ll give you a full refund!]                                                                                                                                                                                                                                                                                                       |[]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |39.99 |[{thumb -> https://m.media-amazon.com/images/I/41WGHJs4LRL._AC_US40_.jpg, large -> https://m.media-amazon.com/images/I/41WGHJs4LRL._AC_.jpg, variant -> MAIN, hi_res -> https://m.media-amazon.com/images/I/713xlga6r2L._AC_SL1500_.jpg}, {thumb -> https://m.media-amazon.com/images/I/516fyzKyHcL._AC_US40_.jpg, large -> https://m.media-amazon.com/images/I/516fyzKyHcL._AC_.jpg, variant -> PT01, hi_res -> https://m.media-amazon.com/images/I/91DVVvCpkzL._AC_SL1500_.jpg}, {thumb -> https://m.media-amazon.com/images/I/51VDxa6qCWL._AC_US40_.jpg, large -> https://m.media-amazon.com/images/I/51VDxa6qCWL._AC_.jpg, variant -> PT02, hi_res -> https://m.media-amazon.com/images/I/81em1viMJ2L._AC_SL1500_.jpg}, {thumb -> https://m.media-amazon.com/images/I/415RDk1YceL._AC_US40_.jpg, large -> https://m.media-amazon.co ...
# |B00AVWKUJS |11768       |3.5427430319510536|Office Products|Canon Office and Business MX922 All-in-One Printer, Wireless and Mobile Printing                                                                                                                       |3.9           |15290        |[Features: Wireless LAN,AirPrint, Google Cloud Print, Wireless Printing, Mobile Device Printing,USB 2.0 Hi-Speed: Plug the cable into your PC for a super-fast connection for your data transfers., Fully-Integrated, 35-sheet Duplex Auto Document Feeder: Easily copy, scan and fax multiple documents without having to load them one page at a time, Built-In Auto Duplex Printing: Automatically print on both sides of the page without the hassle of turning it over manually, Compatible with Individual/Combo CLI-251 XL Ink Tanks (Cyan, Magenta, Yellow, Black) & PGI-250 XL Or PGI-255 XXL Pigment Black Ink Tanks., 20-Foot cord.OS Compatibility:Windows 8, Windows RT, Windows 7, Windows 7 SP1, Windows Vista SP1, Vista SP2, Windows XP SP3 32-bit and Mac OSX 10.6.8 - 10.9.x]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |[Product Description, The Canon PIXMA MX922 Energy Star Wireless Inkjet Office All-in-One Printer prints in black and white at 15 ipm, in color at 10 ipm, and can output a borderless 4.0 x 6.0-inch photo in 21 seconds. Print borderless photos right at home using the 9600 x 2400 color dpi. Use the automatic double-sided print feature to print on both sides of the page and cut your paper consumption by as much as 50%. The built-in disc tray lets you design and print your own custom CDs, DVDs, and Blu-rays. Its Full HD Movie Print feature takes a frame from an HD movie recorded on a compatible EOS, PowerShot, or VIXIA camera or camcorder and prints it as a photo, ensuring you never miss a photo opportunity while shooting video. The MX922 features a scan resolution of up to 2400 x 4800 dpi optical. Plus use the built-in copy function to duplicate photos as well as documents., Set Contains:, PIXMA MX922 Wireless Inkjet Office All-In-One CD/DVD Printing Tray Manuals and other documents Matte Photo Paper (For Automatic Print Head Alignment) Setup CD-ROM Setup Ink Tanks Power Cord Telephone Line Cable]|499.99|[{thumb -> https://m.media-amazon.com/images/I/41rujl2mWML._AC_US40_.jpg, large -> https://m.media-amazon.com/images/I/41rujl2mWML._AC_.jpg, variant -> MAIN, hi_res -> NULL}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# |B0BM61RCJQ |22215       |4.3279765923925275|Office Products|Everlasting Comfort Car Seat Cushion for Tailbone Pain Relief - Office Chair Cushion w/Premium ComfortFoam™ for All-Day Sitting Support - Coccyx, Sciatica Pain Relief Pillow for Desk Chair and Gaming|4.4           |96511        |[EFFECTIVE PAIN RELIEF: Get relief from lower back, coccyx, and sciatica pain with our desk chair cushion. The tailbone pain relief cushion evenly distributes weight to reduce pressure and pain, ALL DAY SUPPORT: Enjoy lasting comfort during 8+ hr workdays with our coccyx cushion for tailbone pain. Made with ComfortFoam, it contours to your bottom using body heat while never flattening, ERGONOMIC DESIGN for IMPROVED POSTURE: Our lower back support for office chair cushion includes a unique U shaped coccyx cutout, that promotes proper spinal alignment and improves posture, CERTIFIED SAFE MATERIALS: Our chair pillow has been tested by OEKO-TEX to earn the coveted STANDARD 100 label meaning every component is certified safe and harmless for both you and the environment, CHAIR CUSHIONS for COMFORT: Our seat cushions for office chairs are designed for your comfort, providing a comfortable seating experience for prolonged sitting periods at work, travel, or home use, VERSATILE: Ideal as a seat cushion for tailbone pain relief, sciatica pain relief pillow, car seat cushions for driving, donut seat cushion, cushion for office chair, tailbone pillow and coccyx cushion, SIT COOL and DRY: Our seat cushion for sciatica pain relief is designed to keep you cool, dry, and comfortable. The breathable, moisture wicking cover helps prevent sweating due to prolonged sitting, LIGHTWEIGHT and PORTABLE: Conveniently sized, take our donut cushion for tailbone pain with you anywhere you go. Use it in your home office, in the car, or on an airplane so you'll always sit comfortably, EASY to CLEAN: We've made it easy to keep your office chair cushion for butt fresh and hygienic. Unzip and remove the plush cover and toss in the wash, then tumble dry. Please do not wash memory foam]|[]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |47.99 |[{thumb -> https://m.media-amazon.com/images/I/41GtAaAvdPL._AC_US40_.jpg, large -> https://m.media-amazon.com/images/I/41GtAaAvdPL._AC_.jpg, variant -> MAIN, hi_res -> https://m.media-amazon.com/images/I/81+vxhDoWBL._AC_SL1500_.jpg}, {thumb -> https://m.media-amazon.com/images/I/51fOR8lEIlL._AC_US40_.jpg, large -> https://m.media-amazon.com/images/I/51fOR8lEIlL._AC_.jpg, variant -> PT01, hi_res -> https://m.media-amazon.com/images/I/71IMoJovZoL._AC_SL1500_.jpg}, {thumb -> https://m.media-amazon.com/images/I/41vOjzx35lL._AC_US40_.jpg, large -> https://m.media-amazon.com/images/I/41vOjzx35lL._AC_.jpg, variant -> PT03, hi_res -> https://m.media-amazon.com/images/I/616x8i46vML._AC_SL1500_.jpg}, {thumb -> https://m.media-amazon.com/images/I/51d+MeweJEL._AC_US40_.jpg, large -> https://m.media-amazon.co ...
# |B087S2JRXY |32645       |4.139378158982999 |Office Products|Amazon Basics 15-Sheet Cross-Cut Paper, CD Credit Card Office Shredder                                                                                                                                 |4.6           |201726       |[15 sheet crosscut paper/CD/credit card shredder, Shred size of 3/16" x 1-7/32" (4.7 x 31mm), security level P-4, 20 minute continuous run time, Overheat / Overload protection, LED indicators: Standby/Overheat/Overload/Door open/Bin full, 6 gallon pullout basket/ Casters included, 4-mode switchAuto/Off/Forward/Reverse, Also destroys CD/DVD, credit card, staples, Small Paper Clips, Important Note: Do not spray or keep any aerosol products in or around the shredder and do not shred items like metallic credit cards]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |[Product Description, Amazon Basics 15-Sheet Cross-Cut Paper, CD Credit Card Office Shredder, From the Manufacturer, Amazon Basics]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |131.99|[{thumb -> https://m.media-amazon.com/images/I/41e3xGeJ3ZL._AC_US40_.jpg, large -> https://m.media-amazon.com/images/I/41e3xGeJ3ZL._AC_.jpg, variant -> MAIN, hi_res -> https://m.media-amazon.com/images/I/81uieoPhSzL._AC_SL1500_.jpg}, {thumb -> https://m.media-amazon.com/images/I/31PEySBxgXS._AC_US40_.jpg, large -> https://m.media-amazon.com/images/I/31PEySBxgXS._AC_.jpg, variant -> PT01, hi_res -> https://m.media-amazon.com/images/I/71uheMpyuqS._AC_SL1500_.jpg}, {thumb -> https://m.media-amazon.com/images/I/51A45vbX57L._AC_US40_.jpg, large -> https://m.media-amazon.com/images/I/51A45vbX57L._AC_.jpg, variant -> PT02, hi_res -> https://m.media-amazon.com/images/I/91D6zFvAAhL._AC_SL1500_.jpg}, {thumb -> https://m.media-amazon.com/images/I/41fYQzDDC0L._AC_US40_.jpg, large -> https://m.media-amazon.co ...
# |B0BSYNLRBY |11221       |4.195882719900188 |Amazon Home    |Custom Self-Inking Stamp - Up to 3 Lines - 11 Color Choices and 17 Font Choices (Extra Large)                                                                                                          |4.5           |66103        |[Personalize up to 3 lines of text on this customizable self-inking stamp. Use your stamp for return addresses, custom labels and more., Self-inking design allows for quick, repetitive stamping, and a clear mount bottom allows you to accurately line up your impression., Re-inkable, replaceable ink pad is available in 11 ink colors: black, red, blue, green, purple, brown, orange, mint, turquoise, pink, 4 impression sizes available - Small: 9/16" x 1-1/2" - Medium: 11/16" x 1-7/8" - Large: 15/16" x 2-3/8" - Extra Large: 1-1/8" x 2-11/16"]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |[]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |19.99 |[{thumb -> https://m.media-amazon.com/images/I/51kbCsdFKGL._AC_US75_.jpg, large -> https://m.media-amazon.com/images/I/51kbCsdFKGL._AC_.jpg, variant -> MAIN, hi_res -> https://m.media-amazon.com/images/I/718k0Hh1RmL._AC_SL1500_.jpg}, {thumb -> https://m.media-amazon.com/images/I/51wxMFfgOlL._AC_US75_.jpg, large -> https://m.media-amazon.com/images/I/51wxMFfgOlL._AC_.jpg, variant -> PT01, hi_res -> https://m.media-amazon.com/images/I/71rnaljnPEL._AC_SL1500_.jpg}, {thumb -> https://m.media-amazon.com/images/I/41YT9qRzzuL._AC_US75_.jpg, large -> https://m.media-amazon.com/images/I/41YT9qRzzuL._AC_.jpg, variant -> PT02, hi_res -> https://m.media-amazon.com/images/I/71YfQLDHl7L._AC_SL1500_.jpg}, {thumb -> https://m.media-amazon.com/images/I/51Unxun7crL._AC_US75_.jpg, large -> https://m.media-amazon.co ...
# +-----------+------------+------------------+---------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------+-------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...

# %%
top_items.select("parent_asin", "review_count", "avg_rating", col("average_rating").alias("avg_rating_meta"), col("rating_number").alias("rating_number_meta")).show(truncate=False)
# Out:
# +-----------+------------+------------------+---------------+------------------+
# |parent_asin|review_count|avg_rating        |avg_rating_meta|rating_number_meta|
# +-----------+------------+------------------+---------------+------------------+
# |B0BZ67T58M |12135       |4.852575195714874 |4.8            |44539             |
# |B00AVWKUJS |11768       |3.5427430319510536|3.9            |15290             |
# |B087S2JRXY |32645       |4.139378158982999 |4.6            |201726            |
# |B0BM61RCJQ |22215       |4.3279765923925275|4.4            |96511             |
# |B0BSYNLRBY |11221       |4.195882719900188 |4.5            |66103             |
# +-----------+------------+------------------+---------------+------------------+

# %% [markdown]
# ### 5 stars items

# %%
max_rating_asins = review_stat.filter(col("avg_rating") == 5)

# %%
max_rating_items = max_rating_asins.join(meta_df, on="parent_asin", how="left")

# %%
max_rating_items.count()
# Out:
# 266262

# %%
max_rating_items \
  .select("review_count", "avg_rating", col("average_rating").alias("avg_rating_meta"), col("rating_number").alias("rating_number_meta")) \
  .describe().show()
# Out:
# +-------+------------------+----------+------------------+------------------+
# |summary|      review_count|avg_rating|   avg_rating_meta|rating_number_meta|
# +-------+------------------+----------+------------------+------------------+
# |  count|            266262|    266262|            266262|            266262|
# |   mean|1.9671451427541293|       5.0| 4.666156642705357| 39.28364918764225|
# | stddev|2.2119748910160064|       0.0|0.4680049011592168| 538.6512404951242|
# |    min|                 1|       5.0|               1.0|                 1|
# |    max|               105|       5.0|               5.0|            179082|
# +-------+------------------+----------+------------------+------------------+

# %%
max_rating_items.filter(col("review_count") == 1).count()
# Out:
# 167593

# %%
167593 / 266262
# Out:
# 0.6294289083684491

# %% [markdown]
# ## Time

# %% [markdown]
# ### Parse

# %%
from pyspark.sql.functions import to_date, year, month, dayofmonth, from_unixtime

time_parsed_df = (
    joined_df
    .withColumn(
        "ts",
        from_unixtime(col("timestamp") / 1000)
    )
    .withColumn("date", to_date("ts"))
    .withColumn("year", year("ts"))
    .withColumn("month", month("ts"))
    .withColumn("day", dayofmonth("ts"))
)

# %%
time_parsed_df.describe().show()
# Out:
# +-------+--------------------+--------------------+------------------+------------------+--------+--------------------+--------+--------------------+-------------------+------------------+-----------------+------------------+
# |summary|         parent_asin|                asin|      helpful_vote|            rating|    text|           timestamp|   title|             user_id|                 ts|              year|            month|               day|
# +-------+--------------------+--------------------+------------------+------------------+--------+--------------------+--------+--------------------+-------------------+------------------+-----------------+------------------+
# |  count|            12845712|            12845712|          12845712|          12845712|12845712|            12845712|12845712|            12845712|           12845712|          12845712|         12845712|          12845712|
# |   mean|1.8232148177332816E9|2.2490396487819705E9|0.8696842962071701| 4.207478417700786|Infinity|1.551853537519765...|     NaN|                NULL|               NULL| 2018.691617405092|6.329502872242504|15.674615233472462|
# | stddev|1.8524777121534243E9|2.4499065896943507E9|18.395020155343484|1.3521976069953974|     NaN|9.242054393718156E10|     NaN|                NULL|               NULL|2.9474628261796383|3.580115377626671| 8.778162158516668|
# |    min|          0000306002|          0000306002|                -1|               0.0|        |        908165260000|       !|AE22222X4BO3JQVOM...|1998-10-12 04:07:40|              1998|                1|                 1|
# |    max|          BT008UKTMW|          BT008UKTMW|             41687|               5.0|    🫶🏻|       1694551741607|    🫶🏽|AHZZZZPE45DYV2WZ2...|2023-09-12 20:49:01|              2023|               12|                31|
# +-------+--------------------+--------------------+------------------+------------------+--------+--------------------+--------+--------------------+-------------------+------------------+-----------------+------------------+

# %% [markdown]
# ### Review count by date

# %%
count_by_date = time_parsed_df.groupBy("date").count().orderBy("date")

# %%
count_by_date.show()
# Out:
# +----------+-----+
# |      date|count|
# +----------+-----+
# |1998-10-12|    1|
# |1998-11-04|    1|
# |1998-12-27|    1|
# |1999-06-08|    1|
# |1999-06-22|    1|
# |1999-06-30|    1|
# |1999-07-05|    1|
# |1999-07-07|    1|
# |1999-07-09|    1|
# |1999-07-14|    1|
# |1999-07-18|    1|
# |1999-08-02|    1|
# |1999-08-03|    1|
# |1999-08-09|    1|
# |1999-08-16|    1|
# |1999-08-22|    1|
# |1999-08-23|    1|
# |1999-08-26|    1|
# |1999-09-26|    1|
# |1999-09-28|    1|
# +----------+-----+
# only showing top 20 rows

# %%
count_by_date_pd = count_by_date.toPandas()

# %%
import pandas as pd

count_by_date_pd['date'] = pd.to_datetime(count_by_date_pd["date"])

# %%
plt.figure(figsize=(12, 6))
plt.plot(count_by_date_pd['date'], count_by_date_pd['count'], linestyle='-', linewidth=0.7)
plt.xlim(pd.Timestamp("2008-01-01"), pd.Timestamp("2024-12-31"))
plt.xlabel("Date")
plt.ylabel("Review count")
plt.title("Review count by date")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Review count by year

# %%
count_by_year = time_parsed_df.groupBy("year").count().orderBy("year")

# %%
count_by_year_pd = count_by_year.toPandas()

# %%
# plt.figure(figsize=(12, 6))
plt.plot(count_by_year_pd['year'], count_by_year_pd['count'], marker='o')
# plt.xlim(pd.Timestamp("2008-01-01"), pd.Timestamp("2024-12-31"))
plt.xlabel("Year")
plt.ylabel("Review count")
plt.title("Review count by year")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Review count by month

# %%
count_by_month = time_parsed_df.groupBy("month").count().orderBy("month")

# %%
count_by_month_pd = count_by_month.toPandas()

# %%
plt.bar(range(1, 13), count_by_month_pd['count'])
plt.xlabel("Month")
plt.ylabel("Review count")
plt.title("Review count by month")
plt.xticks(range(1, 13))
plt.grid(True)
plt.show()

# %% [markdown]
# ### Review trending

# %%
from pyspark.sql.functions import count, avg

trend = time_parsed_df \
              .groupBy("year", "month") \
              .agg(
                  count("*").alias("count"),
                  avg("rating").alias("avg_rating")
              ) \
              .orderBy("year", "month")

# %%
trend_pd = trend.toPandas()

# %%
trend_pd_filtered = trend_pd[trend_pd['count'] >= 1000]

fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(8, 8))

year_ticks = trend_pd_filtered[trend_pd_filtered['month'] == 1 & trend_pd_filtered['year'].mod(5).eq(0)]

axes[0].plot(trend_pd_filtered['count'], linestyle='-', marker='.', linewidth=0.7, c='orange')
axes[0].set_ylabel("Review count")
axes[0].set_title("Review count by month")
axes[0].set_xticks(year_ticks.index)
axes[0].set_xticklabels(year_ticks["year"])
axes[0].grid(True)

axes[1].plot(trend_pd_filtered['avg_rating'], linestyle='--', marker='.', linewidth=0.7)
axes[1].set_ylabel("Avg rating by month")
axes[1].set_title("Avg rating by month")
axes[1].set_xticks(year_ticks.index)
axes[1].set_xticklabels(year_ticks["year"])
axes[1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Verified Purchase

# %% [markdown]
# ### Ratio

# %%
verified_count = joined_df.filter(col("verified_purchase") == True).count()

# %%
verified_count, verified_count / joined_df.count()
# Out:
# (11999060, 0.9340906911193401)

# %% [markdown]
# ### Rating compare

# %%
joined_df.groupBy("verified_purchase").agg(
    avg("rating").alias("avg_rating")
).show()
# Out:
# +-----------------+-----------------+
# |verified_purchase|       avg_rating|
# +-----------------+-----------------+
# |             true|4.220628115869077|
# |            false|4.021116113822444|
# +-----------------+-----------------+

# %% [markdown]
# ### Rating distribution (non-verified vs verified)

# %%
from pyspark.sql.functions import when

avg_rating_by_verified = joined_df.groupBy("parent_asin").agg(
    avg(when(col("verified_purchase") == True, col("rating"))).alias("verified_avg_rating"),
    avg(when(col("verified_purchase") == False, col("rating"))).alias("non_verified_avg_rating")
)

# %%
avg_rating_by_verified = avg_rating_by_verified.toPandas()

verified_avg_ratings = avg_rating_by_verified['verified_avg_rating']
non_verified_avg_ratings = avg_rating_by_verified['non_verified_avg_rating']

# %%
bins = 45

plt.figure(figsize=(12, 6))
plt.hist(verified_avg_ratings, bins=bins, alpha=0.6, density=True)
plt.hist(non_verified_avg_ratings, bins=bins, alpha=0.6, density=True)
plt.legend(["Verified", "Non-verified"])
plt.xlabel("Avg rating")
plt.ylabel("Density")
plt.yscale("log")
plt.title("Avg rating distribution (log scaled)")
plt.grid(True)
plt.show()
